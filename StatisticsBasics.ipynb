# %% [markdown]
# # Statistics Basics

# %% [markdown]
# 1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss nominal, ordinal, interval, and ratio scales.
#   - Types of Data:
#     1. Qualitative Data:
# Refers to non-numeric information that describes qualities or characteristics.
#  Examples:
# Eye color (blue, brown, green).
#     2. Quantitative Data:
# Refers to numeric information that can be measured or counted. Examples:
# Height of individuals in centimeters.
#   - 1. Nominal Scale:
# Characteristics: Data is grouped into categories without any particular order.
#   - 2. Ordinal Scale:
# Characteristics: Data is categorized with a meaningful order, but the intervals between categories are not uniform.
#   - 3. Interval Scale:
# Characteristics: Numeric data with meaningful intervals between values, but no true zero point.
#   -Ratio Scale:
# Characteristics: Numeric data with both meaningful intervals and a true zero point.
#
# 2. What are the measures of central tendency, and when should you use each? Discuss the mean, median,
# and mode with examples and situations where each is appropriate.
#   - The measures of central tendency—mean, median, and mode—help summarize a dataset by identifying a central or typical value. Each measure has specific uses depending on the nature of the data and the situation.
#   - 1. Mean (Average)
# Definition: The mean is calculated by summing all the data values and dividing by the total number of values.
#   - Example: Suppose you have the following exam scores: 70, 85, 90, 75, and 80.
#
# Mean
# =
# 70
# +
# 85
# +
# 90
# +
# 75
# +
# 80
# 5
# =
# 80
# When to Use:
# When data is numerical and evenly distributed.
#   - 2.The median is the middle value in a sorted dataset. If the dataset has an even number of values, the median is the average of the two middle values.
#
# Example: For the dataset {3, 8, 14, 15, 20}, the median is 14 (middle value). If the dataset is {3, 8, 14, 15, 20, 25}, the median is:
#
# Median
# =
# 14
# +
# 15
# 2
# =
# 14.5
#   - When to Use;
# When the dataset contains outliers or skewed values.
#   - 3. Mode
# Definition: The mode is the most frequently occurring value(s) in a dataset.
#
# Example: In the dataset {2, 3, 3, 4, 5, 6, 3}, the mode is 3 (appears most frequently).
# - When to Use:
# For categorical or non-numeric data to find the most common category.
#
# 3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
#   - Dispersion refers to the extent to which data values are spread out or scattered around a central value (like the mean). It provides insight into the variability, consistency, or diversity within a dataset.
#   - Variance: Measures the average squared deviation of each data point from the mean.
#   - Standard Deviation: The square root of the variance, expressed in the same units as the data.
#
# 4. What is a box plot, and what can it tell you about the distribution of data?
#   - A box plot (or box-and-whisker plot) is a graphical representation of data distribution that provides insights into its spread, central tendency, and potential outliers. It is especially useful for visualizing and comparing datasets.
#
# 5. Discuss the role of random sampling in making inferences about populations.
#   - Role of Random Sampling in Making Inferences:
#    - Representation of Population- Random sampling increases the likelihood that the sample reflects the diversity and characteristics of the entire population.
#    - Unbiased Estimates: Because random sampling does not favor certain individuals or groups, it reduces systematic errors.
#
# 6.  Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
#   - Skewness is a statistical measure that describes the asymmetry of a dataset’s distribution relative to a normal (symmetrical) distribution.
#   - Types of Skewness:
#     - Positive Skew (Right Skew): The tail on the right side of the distribution is longer.
#     - Negative Skew (Left Skew): The tail on the left side of the distribution is longer.
#   - How Skewness Affects Data Interpretation:
#     - Impact on Central Tendency: In positively skewed data, the mean will be greater than the median due to the influence of extreme values.
#     - Effect on Variability: Skewed distributions make measures like standard deviation less informative as outliers disproportionately increase the spread.
#
# 7. What is the interquartile range (IQR), and how is it used to detect outliers?
#   - The interquartile range (IQR) is a measure of statistical dispersion that describes the spread of the middle 50% of a dataset. It helps identify how data is distributed and is often used to detect outliers.
#   - How is the IQR Used to Detect Outliers?
#     - Outlier Boundaries: Outliers are data points that fall far outside the range of typical values.
#     - Identifying Outliers: Any data point less than the lower bound or greater than the upper bound is considered an outlier.
#
# 8. Discuss the conditions under which the binomial distribution is used.
#   - The binomial distribution is used to model the probability of observing a specific number of successes in a series of independent trials, where each trial has only two possible outcomes.
#   - Conditions for Using the Binomial Distribution:
#     - Fixed Number of Trials (n): The experiment must involve a predetermined and finite number of trials.
#     - Two Possible Outcomes: Each trial must result in one of two mutually exclusive outcomes (commonly referred to as "success" and "failure").
#
#
# 9.  Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).
#   - The normal distribution, also called the bell curve or Gaussian distribution, is one of the most commonly used probability distributions in statistics. Here are its key properties:
#     - Symmetry: The curve is perfectly symmetrical about the mean(𝜇).
#     - Mean, Median, and Mode: For a normal distribution, the mean, median, and mode are identical and located at the center of the distribution.
#
# 10. Provide a real-life example of a Poisson process and calculate the probability for a specific event.
#   - Poisson Process: Real-Life Example: Suppose a customer service center receives an average of 20 calls per hour.
#
# 11. Explain what a random variable is and differentiate between discrete and continuous random variables.
#   - A random variable is a numerical representation of the outcomes of a random phenomenon or experiment.
#   - 1. Discrete Random Variables:A random variable is discrete if it can take on a finite or countable number of values.
#   - 2. Continuous Random Variables: A random variable is continuous if it can take on an infinite number of values within a range.
#
#
# 12. Provide an example dataset, calculate both covariance and correlation, and interpret the results.
#   - Example Dataset
# Here’s a small dataset with two variables:
#
# Variable X: Number of study hours per day — [2, 3, 4, 5, 6]
#
# Variable Y: Test scores (out of 100) — [50, 60, 65, 70, 80]
#   - Calculate Covariance: Covariance measures how two variables change together. The formula is:
#
# Cov(X, Y)
# =
# ∑
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# 𝑛
# −
# 1
#   -Calculate Correlation: Correlation quantifies the strength and direction of the relationship, scaled between -1 and 1. The formula is:
#
# Corr(X, Y)
# =
# Cov(X, Y)
# 𝜎
# 𝑋
# ⋅
# 𝜎
# 𝑌
